# %% [markdown]
# # Getting Started: Python Fundamentals
# ## Practice Problems

# %% [markdown]
# ### 1. What types are involved in the following expressions? What data type will each expression evaluate to?
#
# `8 * 2.5`

# %%
# Your code here
a=8
b=2.5
mult=8*2.5
print("variable a type is:",type(a))
print("variable b type is:",type(b))
print("variable mult type is:",type(mult))
# Out:
# variable a type is: <class 'int'>
# variable b type is: <class 'float'>
# variable mult type is: <class 'float'>

# %% [markdown]
# `9 / 2`

# %%
# Your code here

# %% [markdown]
# `9 // -2`

# %%
# Your code here

# %% [markdown]
# `1.5 * 2 >= 7 - 3`

# %%
# Your code here
c=1.5 * 2 >= 7 - 3
print(c)
# Out:
# False

# %%
print(5 - 2 * 2 ** 3)
# Out:
# -11

# %% [markdown]
# ### 2. In which order will the expressions be evaluated.
#
# `6 * 3 + 7 * 4`
#
#
# <details>
#   <summary>Answer</summary>
#
#   `*` > `*` > `+`
# </details>
#
#
# `5 - 2 * 3 ** 4`
#
# <details>
#   <summary>Answer</summary>
#
#   `**` > `*` > `-`
# </details>
#
# `(5 - 2) * 3 ** 4`
#
# <details>
#   <summary>Answer</summary>
#
#   `(-)` > `**` > `*`
# </details>
#
# `5 + 2 >= 3 * 4`
#
# <details>
#   <summary>Answer</summary>
#
#   `*` > `+` > `>=`
# </details>
