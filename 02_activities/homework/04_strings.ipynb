# %% [markdown]
# # Strings
# ## Practice Problems

# %% [markdown]
# ### 1. Write a multi-line string about anything you want and print it

# %%
# Your code goes here

'''Changes made:

Removed the unnecessary import of TRUE.
Replaced print with return in the function body.
Fixed the else statement to return False.
The function call (is_416_number('(416)-555-5555')) is placed outside the function and properly indented.'''
# Out:
# "Changes made:\n\nRemoved the unnecessary import of TRUE.\nReplaced print with return in the function body.\nFixed the else statement to return False.\nThe function call (is_416_number('(416)-555-5555')) is placed outside the function and properly indented."

# %% [markdown]
# ### 2. Append a "world" to the following word.

# %%
# Your code goes here
